# %%
print("Hello\'s Friends\n Welcome to my page")
name="Abc";
age=19;
marks=88.77
print(f"The name is {name} and age is {age}");
print("The name is %s and marks is %f"%(name,marks));
print("The name is",name,"age is",age);
# Out:
# Hello's Friends
#  Welcome to my page
# The name is Abc and age is 19
# The name is Abc and marks is 88.770000
# The name is Abc age is 19

# %%
a="hello"
b="friend"
C=a + b
print (C)
# Out:
# hellofriend

# %%
a=10
b=20
c=30
a>b & b>c
# Out:
# False

# %%
a=c=20
b=30
F=bin(b)
print(F)
print(c)
d=a==b
print(d)
# Out:
# 0b11110
# 20
# False

# %%
a=100
b=200
c=300
a is b
Q=a>b
W=a!=b
E=a<=b
R=a>=c
T=10+20 & 30+60
Y=a>b | b>c
U=a>20 or 10+4
print("Q is",Q)
print("W is",W)
print("E is",E)
print("R is",R)
print("T is",T)
print("Y is",Y)
print("U is",U)
# Out:
# Q is False
# W is True
# E is True
# R is False
# T is 26
# Y is False
# U is True

# %%
Str="Let\'s Upgrade"
print(Str)
C="y" in Str
print(C)
 
D="g" in Str
print(D)
# Out:
# Let's Upgrade
# False
# True
