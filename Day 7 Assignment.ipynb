# %%
Port1 = {21:"FTP",22:"SSH",23:"telnet",80:"http"}
print("Port1 is:",Port1);
 
Port2 = {value:key for key, value in Port1.items()}
print("Port2 is:",Port2)
# Out:
# Port1 is: {21: 'FTP', 22: 'SSH', 23: 'telnet', 80: 'http'}
# Port2 is: {'FTP': 21, 'SSH': 22, 'telnet': 23, 'http': 80}

# %%
list =[(1,2),(3,4),(5,6),(4,5)]
print([sum(i) for i in list])
# Out:
# [3, 7, 11, 9]

# %%
list = [(1,2,3),[1,2],["a","hit","less"]]
def convert(list): 
  return tuple(list) 
print(convert(list))
# Out:
# ((1, 2, 3), [1, 2], ['a', 'hit', 'less'])
