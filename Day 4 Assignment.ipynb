# %%
a="we think we become; we are a python programmer"
print("String is :",a);
# Out:
# String is : we think we become; we are a python programmer

# %%
A=len(a)
print("length of a",A);
a[40:46]
# Out:
# length of a 46
# 'rammer'

# %%
a[1:11:2]
# Out:
# 'etikw'

# %%
a[::2]
# Out:
# 'w hn ebcm;w r  yhnporme'

# %%
a[::-1]
# Out:
# 'remmargorp nohtyp a era ew ;emoceb ew kniht ew'

# %%
a[-12:]
# Out:
# 'n programmer'

# %%
a[:5:]
# Out:
# 'we th'

# %%
a[41]
# Out:
# 'a'

# %%
a.find("we")
# Out:
# 0

# %%
a.rfind("we")
# Out:
# 20

# %%
 print(a.find("p"))
print(a.index("r"))
# Out:
# 29
# 24

# %%
a.find("programming")
# Out:
# -1

# %%
string = 'letsupgrade'
print(string.islower()) 
string = 'letsupgrade'
print(string.islower())
# Out:
# True
# True

# %%
A="PYTHON"
print(A.isupper())
# Out:
# True

# %%
A="PYTHON"
print(A.islower())
# Out:
# False

# %%
A="python"
print(A.isupper())
# Out:
# False

# %%
A="python"
print(A.islower())
# Out:
# True

# %%
string = 'LETSUPGRADE'
print(string.isupper()) 
string = 'LETSUPGRADE'
print(string.isupper())
# Out:
# True
# True
